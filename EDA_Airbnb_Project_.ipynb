# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhijeetlahane09/capstone_project-/blob/main/EDA_Airbnb_Project_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project Name -  Airbnb NYC project
# **Project Type** - EDA project (Exploratory Data Analyses)
#
# **Contribution** - Individual

# %% [markdown]
# ![airbnb_newyork.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # GitHub Link - [https://github.com/Abhijeetlahane09/capstone_project-.git](https://github.com/Abhijeetlahane09/capstone_project-.git)

# %% [markdown]
# #  Project Summary -

# %% [markdown]
# * **Project Objective:**
#
#   The primary objective of this project is to analyze and derive insights from a dataset containing Airbnb listings and booking information. By exploring this dataset, we aim to understand trends, patterns, and factors influencing property pricing and booking trends within a specific geographical area (e.g., neighborhood groups , neighborhood).
#
#
#
# * **Dataset Information:**
#
#
# 1. **Data Source**: The dataset is sourced from Airbnb, a popular online
#      platform
#      for booking accommodations. It includes historical data on listings, hosts,
#      reviews, and booking details.
#
#
#
#
# 2. **Data Size:** The dataset comprises [48,896] number of row's and [16] number of columns.
#
# 3. **Data Columns:** The dataset includes various columns, with key attributes **such as:**
#         ['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365']

# %% [markdown]
# > **Required Information for Analysis:**
# To accomplish our project objectives, we need to extract and analyze the following key information from the dataset:
#
#
# * **Property Characteristics:** Information about property types (private rooms, intire house/apt, shared rooms) and other features that influence pricing and booking trends.
#
# * **Pricing Data:** Historical pricing information for Airbnb listings, including daily, weekly, and monthly rates. This will be essential for pricing trend analysis.
#
# * **Availability and Occupancy:** Data on property availability, occupancy rates, and seasonal variations in booking rates.
#
# * **Host Information:** Insights into host characteristics,such as the number of properties managed.
#
# * **Geospatial Data:** Latitude and longitude coordinates to visualize property locations on a map and analyze the geographical distribution of listings.
#
# * **Reviews and Ratings:** Review scores from guests, which can provide insights into the quality of listings and factors influencing guest satisfaction.
#
# * **Booking Patterns:** Data on booking frequency, and the factors affecting booking decisions.
#
# * **Time Series Analysis:** Time series data to identify temporal trends in pricing and occupancy.
#
# * **Data Cleaning and Preprocessing:** Ensuring data quality by handling missing values, outliers, and data inconsistencies.

# %% [markdown]
# # Problem Statement:

# %% [markdown]
# **Understanding and Enhancing Airbnb Data Insights and Presentation**
#
# In the realm of Airbnb data analysis, our objective is to deeply comprehend the dataset before we delve into the visualization process. Our journey begins with rigorous data exploration, followed by meticulous cleaning and outlier handling procedures. With a refined dataset in our hands, our focus shifts to crafting insightful and visually appealing charts that illuminate various facets of the Airbnb listings.
#
# 1. **Average Price by Room Type:**
# Objective: To unveil the pricing patterns based on different room types.
# Insight: Understanding the price differentials between entire homes, private rooms, and shared spaces.
#
# 2. **Room Type Preference:**
# Objective: Analyzing user preference for different room types and their booking frequency.
# Insight: Identifying which room types are preferred by guests, providing valuable market insights.
#
# 3. **Room Type Preference in Different Neighborhoods:**
# Objective: Examining room type preferences within different neighborhood groups.
# Insight: Discovering how room preferences vary across diverse neighborhoods, aiding in strategic marketing efforts.
#
# 4. **Geographical Map Listings:**
# Objective: Mapping the geographic distribution of listings.
# Insight: Visualizing where listings are concentrated geographically, helping identify popular areas.
#
# 5. **Seasonal Trends in Line Chart:**
# Objective: Identifying pricing trends across different seasons.
# Insight: Recognizing fluctuations in pricing based on seasonal demand, enabling optimized pricing strategies.
#
# 6. **Time Series Line Chart:**
# Objective: Understanding the trend and pattern of the average number of reviews over time.
# Insight: seasonal patterns where certain months have significantly higher average review counts.
#
# 7. **Neighborhood Groups Host Listing Count:**
# Objective: Analyzing the distribution of host listings within neighborhood groups.
# Insight: Understanding the density of hosts in different neighborhood clusters.
#
# 8. **Neighborhood Group Popularity:**
# Objective: Identifying the popularity of neighborhood groups based on reviews per months.
# Insight: Pinpointing the most popular neighborhood groups for potential visitors and investors.
#
# 9. **Top Neighborhood Groups by Listing Count:**
# Objective: Recognizing the top neighborhood groups based on the number of listings.
# Insight: Understanding the areas with the highest concentration of Airbnb listings.
#
# 10. **Availability by Neighborhood Groups:**
# Objective: Analyzing the availability of listings within neighborhood groups.
# Insight: Revealing which neighborhood groups have higher or lower availability, aiding in demand forecasting.
#
# 11. **Correlation Heat Map:**
# Objective: Identifying correlations among key attributes like price, reviews, and availability.
# Insight: Understanding how different factors influence each other, guiding business decisions.
#
# 12. **Price Distribution:**
# Objective: Visualizing the distribution of listing prices.
# Insight: Understanding the range and spread of prices, crucial for market positioning.
#
# 13. **Number of Reviews vs Price:**
# Objective: Analyzing the relationship between the number of reviews and listing prices.
# Insight: Determining if higher prices correlate with more or fewer reviews, indicating customer satisfaction.
#
# 14. **Average Price by Neighborhood Groups:**
# Objective: Comparing average prices across different neighborhood groups.
# Insight: Identifying the cost dynamics in various neighborhood clusters.
#
# 15. **Top Hosts by Property Count:**
# Objective: Recognizing hosts with the highest number of properties.
# Insight: Understanding prolific hosts, potentially indicating successful Airbnb business strategies.
#
# 16. **Most Expensive Hosts:**
# Objective: Identifying hosts with the highest property prices.
# Insight: Recognizing premium offerings in the Airbnb market, understanding luxury property trends.
#
# By delving into these visualizations, we aim to extract valuable insights, uncover hidden trends, and offer actionable recommendations for both Airbnb hosts and potential guests. Through this comprehensive analysis, we strive to empower stakeholders with the knowledge required to make informed decisions and enhance their Airbnb experience.

# %% [markdown]
# # Let's Begin !

# %% [markdown]
# >  Lets begin with importing required libriries for EDA

# %%
# importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %% [markdown]
# > Lets get familiar with our dataset

# %%
# importing data form csv file uploaded on google drive
airbnb_df = pd.read_csv("/content/drive/MyDrive/practice files/Airbnb NYC 2019.csv")

# %%
# lets have a look at the data .
airbnb_df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
# bottom view of the data
airbnb_df.tail()
# Out:
#              id                                               name   host_id  \
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# 48890        Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891        Marisol            Brooklyn            Bushwick  40.70184
# 48892  Ilgar & Aysel           Manhattan              Harlem  40.81475
# 48893            Taz           Manhattan      Hell's Kitchen  40.75751
# 48894     Christophe           Manhattan      Hell's Kitchen  40.76404
#
# ...

# %%
# view of all columns in airbnb df
airbnb_df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %% [markdown]
# > **Here is the information about what this columns contains**
#
# 1. **id:** A unique identifier for each Airbnb listing.
# 2. **name:** The title or name of the listing as provided by the host.
# 3. **host_id:** A unique identifier for each host who lists properties on Airbnb.
# 4. **host_name:** The name of the host or property owner.
# 5. **neighbourhood_group:** The larger administrative division of New York City (e.g., Manhattan, Brooklyn)
# 6. **neighbourhood:** The specific neighborhood or area where the property is located.
# 7. **latitude:** Geographic latitude coordinates of the property.
# 8. **longitude:** Geographic longitude coordinates of the property.
# 9. **room_type:** The type of room or accommodation being offered (e.g., entire home/apartment, private room, shared room).
# 11. **price:** The nightly rental price for the listing.
# 12. **minimum_nights:** The minimum number of nights required for booking.
# 13. **number_of_reviews:** The total number of reviews for the listing.
# 14. **last_review:** The date of the last review left by a guest.
# 15. **reviews_per_month:** The average number of reviews received per month.
# 16. **calculated_host_listings_count:** The number of listings the host has on Airbnb, calculated from this property.
# 15. **availability_365:** The number of available nights for booking in the next 365 days.
# These columns provide essential information about the Airbnb listings in New York City in 2019.

# %%
# lets have the additional info about not null values present in data and its data types.
airbnb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
# lets get the discription of data frame such as  count, mean, median, std, min , max and other.
airbnb_df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %% [markdown]
# # **Data cleaning -**

# %% [markdown]
# > **Handling missing values**
# ---
#
# When data is missing from a dataset, it may be represented by other values such as '?' question marks, '-' dashes or blank spaces.
#
# These values can create problems during data analysis as they cannot be recognized as missing data by most software packages and can interfere with calculations and statistics.
#
# By converting these values to NaN (Not a Number), we can standardize the representation of missing data and make it easier to handle and process during data analysis.

# %%
# lets have a look at not null values in a column
# the total count of a non-null value should be 48895, if the colunt is less than 48895 it means that column contain null values
airbnb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# *  As we can see there is some missing values in columns :- ["name",
#    "hoste_name",   "last_review",   "reviews_per_month"  .]

# %%
# the null values in a data frame is already represented by the Nan value
# lets finde how many null records present in a data.
airbnb_df.isna().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# *  **In the "name" and "host_name" column only few rows are missing and its not much  important for further analysis  so we can drop them**

# %%
# lets drop the null records from the name and host name column
airbnb_df.dropna(subset=["name","host_name"],axis= 0 , inplace = True)

# %%
# now you can see there is no null value in name and host_name column
airbnb_df.isna().sum()
# Out:
# id                                    0
# name                                  0
# host_id                               0
# host_name                             0
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10037
# reviews_per_month                 10037
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# * **we cant remove the missing values in last_review and reviews_per_month
# columns, as they contain a huge data, removing them have a bad impact on analysis and we loss the important data.**

# %%
# so we decided to replace the null value of last_review as "Noreviews" and for review_per_month "0" as replacement
airbnb_df['last_review'].fillna('NoReviews', inplace=True)
# firstly we did this step of replacing it to a "NoReviews" but it's causing problem while visualizing the time series trend because its data type so we change it to nat(not a time)

airbnb_df['last_review'] = pd.to_datetime(airbnb_df['last_review'], errors='coerce')
# errors is set to 'coerce', it means that if pandas encounters any errors while converting the data to datetime,
# it will set the problematic entries to NaT (Not a Time) instead of raising an error and stopping the execution of the code.

airbnb_df['reviews_per_month'].fillna(0, inplace=True)
# then we fill the null values in review_per_month column with  0

# %%
# as we can see now the data type of last_review has been changed to datetime
airbnb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48858 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48858 non-null  int64
#  1   name                            48858 non-null  object
#  2   host_id                         48858 non-null  int64
#  3   host_name                       48858 non-null  object
#  4   neighbourhood_group             48858 non-null  object
#  5   neighbourhood                   48858 non-null  object
#  6   latitude                        48858 non-null  float64
#  7   longitude                       48858 non-null  float64
#  8   room_type                       48858 non-null  object
#  9   price                           48858 non-null  int64
#  10  minimum_nights                  48858 non-null  int64
#  11  number_of_reviews               48858 non-null  int64
# ...

# %%
# Checking for duplicate rows
duplicate_rows = airbnb_df.duplicated()

# Filtering the DataFrame to show duplicate rows
duplicate_data = airbnb_df[duplicate_rows]
print(duplicate_data)
# there is no duplicate values present in our data
# Out:
# Empty DataFrame
# Columns: [id, name, host_id, host_name, neighbourhood_group, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []

# %% [markdown]
# # Lets deal with the outlier's -

# %% [markdown]
# * **Minimum nights column**

# %%
# finding the outlier's using boxplot in minimum_nights column
sb.boxplot(y=airbnb_df['minimum_nights'])
plt.title('Box Plot of minimum_nights')
plt.show()

# %%
# here we get the outliers

lower_bound = 1    # we manually assign the lower bount as 1 because its not possiblel to have less than 1 minimum night requirment for booking.
upper_bound = 90  # the reson behind it explained below

outliers_count = ((airbnb_df['minimum_nights'] < lower_bound) | (airbnb_df['minimum_nights'] > upper_bound)).sum()  #  is the count of outliers
outliers_count
# Out:
# 196

# %% [markdown]
# > **The reason behind why we put 90 as upper bound :**
# . Airbnb doesn’t allow properties to be rented out for more than 90 nights per year. If your limit for bookings is reached, Airbnb will automatically close your property until the end of the calendar year. In addition to 90 consecutive days, the 90-day limit also applies to 90 days spread throughout the year.
# * This information is gathered from :- [link to website](https://www.yourairhost.co.uk/airbnb-90-day-rule/#:~:text=Airbnb%20doesn't%20allow%20properties,days%20spread%20throughout%20the%20year.)

# %%
# now we are going to drop this outlires
airbnb_df = airbnb_df[(airbnb_df['minimum_nights'] >= lower_bound) & (airbnb_df['minimum_nights'] <= upper_bound)]

# %%
# as we can see now the outliers has been removed
airbnb_df["minimum_nights"].describe()
# Out:
# count    48662.000000
# mean         6.114484
# std          9.854058
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          5.000000
# max         90.000000
# Name: minimum_nights, dtype: float64

# %% [markdown]
# * **price column**

# %%
# checking for outliers in price
sb.boxplot(y=airbnb_df['price'])
plt.title('Box Plot for price')
plt.show()
# so the highest price is 10000 and it is possible to have such high price in NYC, it can have a luxurious prpperty
#so we are not going to remove them

# %%
# there are some price which is 0 remove them
airbnb_df["price"].describe()
# Out:
# count    48662.000000
# mean       151.891661
# std        228.496734
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
# removing price == 0
airbnb_df = airbnb_df[airbnb_df['price'] != 0]
airbnb_df["price"].describe()
# Out:
# count    48651.000000
# mean       151.926004
# std        228.511148
# min         10.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %% [markdown]
# * **availability_365 column**

# %%
# lets cheq outliers in availability_365
airbnb_df["availability_365"].describe()
# here we can see the minimum availability is 0 it means there is a possibility of the place is booked for entire year
# and the maximum availability is 365 it means that place not even booked for 1 day
# Out:
# count    48651.000000
# mean       112.400115
# std        131.410219
# min          0.000000
# 25%          0.000000
# 50%         44.000000
# 75%        225.000000
# max        365.000000
# Name: availability_365, dtype: float64

# %%
# here we can see the availability is 365(not booked for even 1 day in whole year) but still have some reviews
airbnb_df.head(2)
# Out:
#      id                                name  host_id host_name  \
# 0  2539  Clean & quiet apt home by the park     2787      John
# 1  2595               Skylit Midtown Castle     2845  Jennifer
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    149               1                  9  2018-10-19               0.21
# 1    225               1                 45  2019-05-21               0.38
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355

# %%
# lets remove them
invalid_availability = (airbnb_df["availability_365"] == 365) & (airbnb_df["number_of_reviews"] > 0)
airbnb_df = airbnb_df.loc[~invalid_availability]
airbnb_df.head()
# now we can see the availability of 365 days with more than o reviews are removed
# Out:
#      id                                              name  host_id  \
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5  5099         Large Cozy 1 BR Apartment In Midtown East     7322
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
# 5        Chris           Manhattan   Murray Hill  40.74767  -73.97500
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# # **Data visualizations -**

# %% [markdown]
# >  Let's create visualizations based on the problem statement for analyzing Airbnb listing data in New York City and explain the rationale behind each chart and the insights

# %% [markdown]
# #   Average Price by room type -

# %%
# let's see avrage price by the room type in a table formate
avg_price = airbnb_df.groupby("room_type")["price"].mean().reset_index()
avg_price
# Out:
#          room_type       price
# 0  Entire home/apt  209.593095
# 1     Private room   87.267374
# 2      Shared room   71.384106

# %%
# lest see in a visual bar plot formate
colors = sb.color_palette("Set2")


plt.figure(figsize=(10, 6))  # to asigne the size of the figure

sb.barplot(x='room_type', y='price', data=airbnb_df, palette=colors) # creat a barplot
plt.title('Average Price by Room Type', fontsize=16, fontweight='bold')      # give title
plt.xlabel('Types of Room', fontsize=14)        # assigning xlabel
plt.ylabel('Average Price (USD)', fontsize=14)  # assigning ylabel
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
sb.despine(left=True)
plt.show()                      # show the final plot

# %% [markdown]
# * chart type :- barplot
# * why this chart :- The bar plot is chosen because it provides a clear visual comparison of the average prices between different room types. This chart is suitable when comparing a numerical variable (average price) across different categories (room types).
# * Information Gathered:-
#
# Pricing Strategy: The chart helps hosts and property owners understand the average price expectations for different room types. For example, they can see that "Entire home/apt" listings tend to have higher average prices compared to "Private room" or "Shared room" listings.
#
#
# Customer Expectations: Travelers can gain insights into what to expect in terms of pricing based on their room type preferences. This can help them set realistic budget expectations and make informed booking decisions.

# %% [markdown]
# #  Room type preference -

# %%
# Creating a bar plot using Seaborn, with room_type on the x-axis, number_of_reviews on the y-axis,
# and different room types distinguished by different colors.
plt.figure(figsize=(10, 6))
sb.barplot(x='room_type', y='number_of_reviews', hue='room_type', data=airbnb_df, palette='Set2')
# giving title and increasing size for better view
plt.title('Room Type Preference and Booking Frequency', fontsize=16, fontweight='bold')
# giving x and y label
plt.xlabel('Room Type', fontsize=14)
plt.ylabel('Number of Reviews', fontsize=14)
# Setting the font size of x-axis and y-axis tick labels to 12 for better readability
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# The legend title is set as 'Room Type', and bbox_to_anchor adjusts the position of the legend
plt.legend(title='Room Type', loc='upper right', bbox_to_anchor=(1.2, 1))

# Remove the spines (the lines surrounding the plot) for a cleaner appearance
sb.despine()
# display plot
plt.show()

# %% [markdown]
# * **chart type :** bar chart
# * **why this chart :**  Grouped bar charts are ideal for comparing multiple categories (room types, in this case) within each data point (number of reviews).
#
# * **information gathered  :**
#
#   Private Rooms:
#  Private rooms have the highest booking frequency among users. This could indicate that travelers often prefer the privacy and comfort of a private room during their stay.
# Entire Homes/Apartments: Entire homes/apartments are also popular, suggesting that users appreciate having an entire space to themselves, offering a home-like experience.
# Shared Rooms: Shared rooms have a lower booking frequency compared to private rooms and entire homes/apartments.
#
#   Market Demand:
# The high booking frequency for private rooms and entire homes/apartments indicates a strong market demand for these accommodation types. Hosts might consider focusing on providing these types of accommodations based on user preferences.

# %% [markdown]
# #  Room type preference in different neighourhood -

# %%
# Room Type Preference in Different Neighbourhoods
plt.figure(figsize=(10, 6))
# Group the data by 'neighbourhood_group' and 'room_type', count the number of listings (id's),
# and unstack the data to have 'room_type' as columns and 'neighbourhood_group' as index
room_type_neighbourhood = airbnb_df.groupby(['neighbourhood_group', 'room_type'])['id'].count().unstack()
# giving chart type , colour and size
room_type_neighbourhood.plot(kind='bar', stacked=True, colormap='viridis', figsize=(10, 6))
plt.title('Room Type Preference in Different Neighbourhoods', fontsize=16, fontweight='bold')
plt.xlabel('Neighbourhood Group', fontsize=14)
plt.ylabel('Count', fontsize=14)
# Rotating x-axis labels and increase in font size for better view
plt.xticks(rotation=0, fontsize=12)
plt.yticks(fontsize=12)
# Add a legend to the plot with the title 'Room Type'.
plt.legend(title='Room Type')
sb.despine()
plt.show()

# %% [markdown]
# * **chart type :**  Stacked bar chart
#
# * **why this chart :** Stacked bar charts are excellent for visually comparing parts of a whole (room types) across different categories (neighbourhood groups). The heights of the segments are easily comparable, making it straightforward to identify the dominant room type in each neighbourhood.
#
# * **information gathered :**
#
#   Room Type Distribution: The chart allows us to see the distribution of room types (Entire homes/apartments, Private rooms, and Shared rooms) within each neighbourhood group.
#
#   Preference Patterns: By observing the height of the stacked bars, we can identify the predominant room type preferred by guests in each neighbourhood group. For example, if the 'Entire homes/apartments' section is taller than others, it indicates a higher preference for entire homes/apartments in that neighbourhood.

# %% [markdown]
# #  Geospatial Map of Listings -

# %%
# lets have a look at the geographic distribution
# figure for the scatter plot with specified size (width: 10, height: 7)
plt.figure(figsize =(10,7))
# Creating a scatter plot using latitude as x-axis, longitude as y-axis
sb.scatterplot(x = "latitude", y = "longitude", data = airbnb_df, hue ="neighbourhood_group" )
# title of the plot
plt.title("Geographic distribution", size = 20)
# Display the plot
plt.show()
# Points are colored based on the 'neighbourhood_group' column, providing a visual representation of different neighborhood groups.

# %% [markdown]
# * **Chart Type:** Scatter Plot on a Map
# * **why this chart:**This scatterplot can display the density of Airbnb listings across different neighborhoods in New York City. It helps identify hotspots with high listing concentrations and areas with fewer listings.
# * **Information Gathered:** This chart reveals which neighborhoods or areas have the highest density of listings, helping travelers and hosts understand the most popular regions.

# %% [markdown]
# #  Seasonal trend line chart -

# %%
# Extracting the month from the 'last_review' column and create a new column 'month'
airbnb_df['month'] = airbnb_df['last_review'].dt.month

# Group the data by month and calculate the average price for each month
monthly_avg_price = airbnb_df.groupby('month')['price'].mean()

# Create a time series line chart for the monthly average price
plt.figure(figsize=(10, 6))
plt.plot(monthly_avg_price.index, monthly_avg_price.values, marker='o', color='b', linewidth=2, markersize=8, label='Monthly Average Price')
plt.xlabel('Month', fontsize=14)
plt.ylabel('Average Price', fontsize=14)
plt.title('Seasonal Trend in Airbnb Prices', fontsize=16, fontweight='bold')
# Set x-axis ticks to represent months from January to December
plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'], fontsize=12)
plt.yticks(fontsize=12)
plt.legend()
# Add gridlines to the plot with dashed lines (linestyle='--') and reduced opacity (alpha=0.7)
plt.grid(True, linestyle='--', alpha = 0.7)
# Ensure tight layout for better spacing between elements in the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# * **chart type :** line chart
# * **why this chart :**  The line chart effectively displays the trend over time, making it easy to identify patterns and variations.
#
# * **information gathered :**
#
#   Seasonal Patterns: The chart allows viewers to observe seasonal patterns in Airbnb prices throughout the year. For instance, prices might increase during vacation seasons or special events and decrease during off-peak times.
#
#   Monthly Variations: By looking at the chart, viewers can identify which months generally have higher or lower prices, helping them plan their travels accordingly.
# * **High pick**
#
#   Winter Holidays: In many regions, December is a peak holiday period due to Christmas and New Year's. Families often travel for winter holidays, which can drive up accommodation prices, especially in destinations known for their festive celebrations.
#   Tourist Attractions: Some regions have specific attractions, events, or festivals during December and January, drawing tourists and raising accommodation prices.
# * **low pick**
#
#    Weather: In some regions, August can be very hot, especially in places with a Mediterranean climate. This can lead to a decrease in tourism as people prefer milder weather for their vacations.
# Local Events: Regions might not have major local events or festivals during August, reducing the influx of tourists.
# Off-Peak Tourism: March is often considered an off-peak travel month in many destinations. The holiday season has ended, and schools are usually in session, leading to a decrease in family vacations.

# %% [markdown]
# # Time Series Line Chart -

# %%
# lets create a line chart to finde the trend and seasonality.

airbnb_df['year_month'] = airbnb_df['last_review'].dt.to_period('M')  # Create a new column for year-month

# Group by year and month, then calculate the average number of reviews for each month
monthly_avg_reviews = airbnb_df.groupby('year_month')['number_of_reviews'].mean()

# Plotting the time series line chart
plt.figure(figsize=(18, 7))
plt.plot(monthly_avg_reviews.index.astype(str), monthly_avg_reviews.values, marker='o', linestyle='-')
plt.title('Average Reviews per Month')
plt.xlabel('Year-Month')
plt.ylabel('Average Number of Reviews')
plt.grid(True)
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.tight_layout()        # it automatically adjusts the subplots and other elements of the figure to fit within the figure area.
plt.show()

# %% [markdown]
# * **chart type -** line chart
# * **why this chart -** The choice of a time series line chart was made because it effectively conveys the trend and pattern of the average number of reviews over time.
# * **information gathered-**
#
#  1. Seasonal Patterns: The chart shows clear seasonal patterns where certain months have significantly higher average review counts. These peaks often correspond to vacation seasons or tourist influx periods, indicating increased Airbnb activity during these times.
#
#  2. Yearly Trends: There is a consistent upward trend in average review counts over the years. This suggests a growth in the popularity of Airbnb listings, leading to more reviews being posted annually. It could indicate a general increase in the usage of Airbnb accommodations.
#
#  3. Opportunity for Optimization: Hosts and property owners can use this information to optimize their pricing, availability, and marketing strategies. For example, they can adjust pricing during peak seasons or offer promotions during low activity months to attract more guests.

# %% [markdown]
# #  neighbourhood group host listing count -

# %%
# Grouping the data by "neighbourhood_group" and finding the maximum value of 'calculated_host_listings_count' in each group
# Reset the index to convert the result into a DataFrame
host_areas = airbnb_df.groupby("neighbourhood_group")["calculated_host_listings_count"].max().reset_index()
colors = sb.color_palette("Set2")  # giving a color palette using Seaborn's "Set2"
plt.figure(figsize = (7,9))
# Creating a pie chart with host listing counts, using neighborhood groups as labels and assigned colors
plt.pie(host_areas["calculated_host_listings_count"],labels = host_areas["neighbourhood_group"] , colors= colors)
plt.title("Host listing count by neighbourhood group", size = 15)
plt.show()

# %% [markdown]
# * **chart type :** pie chart
# * **why this chart :** Part-to-Whole Comparison: Pie charts are effective for showing the distribution of a whole (in this case, the maximum calculated host listings count) into its individual parts (neighborhood groups). It's easy to see the relative proportions.
#
#     Limited Categories: Pie charts work well when you have a relatively small number of categories to compare, as you do with neighborhood groups.
#
# * **Information Gathered :**
#
#    1. Comparison of Host Listings: The pie chart allows us to visually compare the calculated host listings count across different neighborhood groups. You can easily identify which neighborhood groups have hosts with the highest maximum listings count.
#
#   2. Host Concentration: The chart highlights whether there is a significant concentration of hosts with a high number of listings in specific neighborhood groups. This information can be useful for both hosts and travelers.

# %% [markdown]
# #  neighbourhood group popularity -

# %%
# calculating total reviews by grouping the data
total_reviews = airbnb_df.groupby('neighbourhood_group')['number_of_reviews'].sum().reset_index()
# creating the data frame of the grouped data
df = pd.DataFrame(total_reviews).sort_values(by = "number_of_reviews", ascending= True)
# Setting the color palette
colors = sb.color_palette("Set2")

# ploting barchart
plt.figure(figsize=(12, 8))
plt.barh(df['neighbourhood_group'], df['number_of_reviews'],  color=colors)

# Set labels and title
plt.xlabel('Total Reviews per Month', fontsize=14)
plt.ylabel('Neighbourhood group', fontsize=14)
plt.title("Neighborhood Popularity: Total Reviews" , fontsize=16, fontweight='bold')


plt.show()

# %% [markdown]
# * **chart type :** barchart
#
# * **why this chart :**  The bar chart provides a visual representation of total reviews.
#
# * **information gathered :**
# The bar lengths represent the total number of reviews received by each    neighborhood, indicating their overall popularity.

# %% [markdown]
# # Top neighborhood groops by listing count  -

# %%
top_n_neighborhoods = 5  # You can adjust this number based on your preference

# Group by 'neighbourhood_group' and 'neighbourhood', count the number of listings, and sort the values
neighborhood_counts = airbnb_df.groupby(['neighbourhood_group', 'neighbourhood']).size().reset_index(name='count')
neighborhood_counts_sorted = neighborhood_counts.sort_values(by=['neighbourhood_group', 'count'], ascending=[True, False])

# Select the top N neighborhoods for each neighborhood group
top_neighborhoods = neighborhood_counts_sorted.groupby('neighbourhood_group').head(top_n_neighborhoods)

# Create a horizontal stacked bar chart for the top N neighborhoods
pivot_table = top_neighborhoods.pivot(index='neighbourhood', columns='neighbourhood_group', values='count')
pivot_table.plot(kind='barh', stacked=True, figsize=(10, 6), colormap='viridis')

plt.title(f'Top {top_n_neighborhoods} Neighborhoods by Listing Count in Each Neighborhood Group')
plt.xlabel('Number of Listings')
plt.ylabel('Neighborhood')
plt.legend(title='Neighborhood Group', bbox_to_anchor=(1, 1))
plt.tight_layout()
plt.show()

# %% [markdown]
# * **chart type :**  Stacked bar chart
# * **why this chart :** The chart allows a clear visual comparison of the total number of listings across different neighborhood groups, This helps in understanding the overall distribution of listings.By stacking the top neighborhoods within each neighborhood group, the chart highlights the most significant neighborhoods, providing a quick overview of the key areas where listings are concentrated.
# * **information Gathered :**In summary, the chart effectively conveys complex information in a visually digestible format. It allows for the identification of listing distribution patterns, highlighting popular neighborhoods, and comparing their popularity within and across different neighborhood groups. The visualization serves as a valuable tool for both quick insights and in-depth analysis of the Airbnb listing distribution.

# %% [markdown]
# #  Availability by neighbourhood_group -

# %%
# lets see wich neighbourhood group is mostly booked or popular
availability = airbnb_df.groupby("neighbourhood_group")["availability_365"].mean()   # lets cheq avrage availability
df = pd.DataFrame(availability).reset_index() # converting to data frame
availability = df.sort_values(by ="availability_365", ascending= True)  # sorting the value for better view

colors = sb.color_palette("Set2")

plt.figure(figsize=(10, 6))
bars = plt.barh(availability["neighbourhood_group"], availability["availability_365"], color=colors, edgecolor='black')  # ploting horizontall barplot
plt.title("Average Availability by Neighbourhood Group", fontsize=16, fontweight='bold')
plt.xlabel("Average Availability (Days)", fontsize=14)
plt.ylabel("Neighbourhood Group", fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
sb.despine(left=True)  # Removing left spine for a cleaner look

plt.show()

# %% [markdown]
# * **chart type :** horizontal barchart
#
# * **why this chart :** A horizontal bar chart is suitable for comparing multiple categories, in this case, different neighborhood groups. It allows for easy comparison of the average availability across groups, and the length of the bars provides a clear visual representation of the differences.
#
# * **information gathered :** The viewer can quickly identify which neighborhood groups are most popular(brooklyn) based on the lower average availability. These groups are likely in high demand among guests, leading to fewer available booking days.
#
#   Conversely, neighborhood groups with higher average availability are less popular(Staten Island) among guests, allowing for more flexible booking options.
#
#   This visualization allows viewers to assess the popularity of different neighborhood groups among Airbnb guests, enabling hosts, travelers, and stakeholders to make informed decisions related to booking properties in New York City.

# %% [markdown]
# # correlation heatmap -

# %%
# Defining a list of selected columns to include in the correlation analysis
selected_columns = ['minimum_nights', 'number_of_reviews', 'reviews_per_month', 'availability_365', 'calculated_host_listings_count', 'price']
# Calculating the correlation matrix using the selected columns
correlation_matrix = airbnb_df[selected_columns].corr()

plt.figure(figsize=(10, 8))
# Generating a heatmap of the correlation matrix with annotations, using the 'coolwarm' color map
# The annotations display the correlation coefficients within the heatmap cells
sb.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlations Among Selected Columns Including Price', fontsize=16, fontweight='bold')
plt.show()

# %% [markdown]
# * **chart type :** correlation heatmap
#
# * **why this chart :** This heatmap allows us to quickly identify which features are strongly correlated. Understanding these correlations can provide insights into how these variables influence each other.
#
# * **information gathered :**
#
#  Minimum Nights vs. Price: There is a weak positive correlation between 'minimum_nights' and 'price'. This suggests that, on average, properties with a slightly higher minimum night requirement tend to have slightly higher prices.
#
#  Number of Reviews vs. Price: There is a weak positive correlation between 'number_of_reviews' and 'price'. This implies that properties with more reviews tend to have slightly higher prices. This could indicate that popular properties, which often receive more reviews, might be priced higher.
#
#  Reviews Per Month vs. Price: The correlation between 'reviews_per_month' and 'price' is also weakly positive. It suggests that properties with a higher monthly review rate might have slightly higher prices.
#
#  Availability vs. Price: There is no strong correlation between 'availability_365' (availability throughout the year) and 'price'. This implies that the availability of a property does not strongly influence its price in this dataset.
#
#  Calculated Host Listings Count vs. Price: There is a weak positive correlation between 'calculated_host_listings_count' and 'price'. This suggests that hosts with more listings tend to price their properties slightly higher.
#
# Overall, these insights provide a nuanced understanding of how different factors interrelate with the pricing of Airbnb listings. It's important to note that the correlations are relatively weak, indicating that these factors alone do not heavily dictate the price. Other unexplored variables might also play significant roles in determining the pricing strategy, and further analysis could uncover additional insights.

# %% [markdown]
# #  Price distribution -

# %%
# lets see the price distribution
plt.figure(figsize=(8, 6))
# creating histogram Using 50 bins and enable kernel density estimation (kde) for a smooth curve
sb.histplot(airbnb_df["price"], bins=50, kde=True, color="skyblue")
plt.title("Price Distribution", fontsize=16, fontweight="bold")
plt.xlabel("Price ($)", fontsize=14)
plt.ylabel("Frequency", fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
# Remove the top and right spines for a cleaner look using Seaborn's 'despine' function
sb.despine()
plt.show()

# %% [markdown]
# * **chart type :** Histogram
#
# * **why this chart :** Clarity in Distribution: The histogram is a straightforward and effective way to visualize the distribution of a numeric variable like prices.
#
# * **information gathered :**
#
#    Right Skewed Distribution:
# The histogram is right-skewed, meaning that the majority of listings have lower prices, and there are a few listings with much higher prices. This suggests that there are relatively few high-end listings, but a larger number of affordable options.
#
#    Common Price Range:
# The peak in the histogram indicates the most common price range for listings. In this case, it appears to be in the lower price range, possibly indicating a significant number of budget-friendly listings.

# %% [markdown]
# #  Number of Reviews vs price -

# %%
plt.figure(figsize=(8, 6))
# Generating a scatter plot using 'number_of_reviews' on the x-axis and 'price' on the y-axis to finde relation between it
sb.scatterplot(x="number_of_reviews", y="price", data=airbnb_df, color="skyblue", edgecolor="black", s=100)

# Set plot labels and title
plt.title("Scatter Plot: Number of Reviews vs Price", fontsize=16, fontweight="bold")
plt.xlabel("Number of Reviews", fontsize=14)
plt.ylabel("Price ($)", fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Display the plot
plt.show()

# %% [markdown]
# * **chart type :** scatter plot
# * **why this chart :** By observing the scatter plot, you can analyze whether there's a correlation between the number of reviews and the price of listings.
#
# * **information gathered :**
#
#   Affordability and Demand: Listings with lower prices are generally more affordable for a larger segment of travelers. Travelers often look for budget-friendly options, especially when exploring high-cost cities like New York City. Hence, lower-priced listings tend to attract more guests, leading to a higher number of reviews.
#
#   Competition: New York City's Airbnb market is highly competitive. Lowering the price might be a strategy employed by hosts to attract more guests, making their listings stand out among the numerous options available.
#
#   Word of Mouth: Affordable and pleasant accommodations often lead to positive word-of-mouth recommendations. Guests who had a good experience at a budget-friendly listing might recommend it to others, resulting in a continuous flow of guests and, consequently, reviews.

# %% [markdown]
# #  Avrage price by Neighbourhood Group -

# %%
# select color for bar's
colors = sb.color_palette("Set2")
# calculating mean of price for every neighbourhood group
avg_price_neighborhood_group = airbnb_df.groupby(["neighbourhood_group"])["price"].mean()
# sorting values to get a better view
df =pd.DataFrame(avg_price_neighborhood_group).reset_index()
avg_price_neighborhood_group = df.sort_values(by="price", ascending=True)

plt.figure(figsize=(10, 6))
# ploting horizontal bar chart
bars = plt.barh(avg_price_neighborhood_group["neighbourhood_group"], avg_price_neighborhood_group["price"], color=colors, edgecolor='black')

# formatting
plt.title("Average Price by Neighbourhood Group", fontsize=16, fontweight='bold')
plt.xlabel("Average Price ($)", fontsize=14)
plt.ylabel("Neighbourhood Group", fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
sb.despine(left=True)  # Removing left spine for a cleaner look

plt.show()

# %% [markdown]
# * **chart type :** horizontal barchart
#
# * **why this chart :** The bar chart effectively displays the average prices for different neighborhood groups. It allows viewers to compare the pricing trends across neighborhood groups at a glance.
#
# * **information gathered :** Price Comparison:
# The chart clearly shows the average prices for each neighborhood group, allowing viewers to identify which groups have higher or lower average prices.
#
#   Market Segmentation:
#   Hosts and property managers can use this information to understand the market segmentation based on neighborhood groups.
#
#   Competitive Analysis:
#   Potential Airbnb hosts can use this chart to analyze the pricing strategies of competitors in different neighborhood groups. It helps in setting competitive yet profitable pricing for their listings.

# %% [markdown]
# #  Top 5 Hosts by property count -

# %%
# top 5 host's who own's most propertys
host_propertys = airbnb_df.groupby(["host_id","host_name"])["calculated_host_listings_count"].mean()  # we chose mean to get sum of all listing by one persone because the count is repeated for every property
host_propertys_df = pd.DataFrame(host_propertys).reset_index()   # creating data frame
host_propertys_df=host_propertys_df.sort_values(by = "calculated_host_listings_count",ascending=False).head(5) # sorting values
colors = sb.color_palette("Set2")

plt.figure(figsize = (8,6))
# creating a simple bar plot
sb.barplot(data=host_propertys_df,x="host_name",y="calculated_host_listings_count", palette=colors)

# formatting
plt.title("Top 5 Hosts in NYC Based on Property Count", fontsize=16, fontweight='bold')
plt.xlabel("Host Name", fontsize=14)
plt.ylabel("Listing Count", fontsize=14)
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)
sb.despine(left=True)


plt.show()

# %% [markdown]
# * **chart type :** bar chart
#
# * **why this chart :** The bar chart is ideal for comparing categories (host names in this case) and their corresponding numerical values (number of listings). It allows for a clear visual comparison between different hosts.
#
# * **information gatherd :**
#
#   Top Hosts: The chart clearly shows the top 5 hosts who own the most properties based on the number of listings they manage. Hosts are ranked from left to right, with the leftmost bar representing the host with the most listings.
#
#   Decision-Making: This chart is valuable for property management and strategic decision-making. Hosts and property management companies can use this information to assess the competition, understand market dynamics, and make informed decisions related to property acquisition, pricing, and marketing strategies.

# %% [markdown]
# #  Most expensive Hosts -

# %%
# most expensive hosts in nyc
# you can change the count of top most expencive hosts
top = 5
# calculating the expencive hosts by the maximum price of there property
expensive_hosts = airbnb_df.groupby(["host_id", "host_name"])["price"].max().reset_index()
# getting in descending order for top most values
top_expensive_hosts = expensive_hosts.sort_values(by = "price", ascending= False).head(top)
# getting totall reviews by that hosts
sum_of_reviews =  airbnb_df.groupby(["host_id", "host_name"])["number_of_reviews"].sum().reset_index()
# joining both tables for further visualization
joined_df = pd.merge(left= top_expensive_hosts, right= sum_of_reviews, how="left" )
joined_df # view in tabular format
# Out:
#     host_id host_name  price  number_of_reviews
# 0  72390391    Jelena  10000                  0
# 1   5143901      Erin  10000                  5
# 2   4382127      Matt   9999                  0
# 3   1235070     Olson   9999                  1
# 4  18128455       Rum   8500                  2

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))

# Bar chart for prices (primary y-axis)
ax1.bar(joined_df['host_name'], joined_df['price'], color='skyblue', label='Price')
ax1.set_xlabel('Host Name', size = 13)
ax1.set_ylabel('Price', color='k', size = 13)
ax1.tick_params(axis='y', labelcolor='k',labelsize = 12)

# Creating a line chart for number of reviews (secondary y-axis)
ax2 = ax1.twinx()
ax2.plot(joined_df['host_name'], joined_df['number_of_reviews'], marker='o', color='orange', label='Total Reviews')
ax2.set_ylabel('Total Reviews', color='k', size = 13)
ax2.tick_params(axis='y', labelcolor='k', labelsize = 12)

plt.title('Top 5 Most Expensive Hosts in NYC', size = 15)
fig.tight_layout()
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %% [markdown]
# * **chart type :** bar & line chart
# * **why this chart :** this chart was chosen because it provides a clear and concise way to compare the prices and review counts of the top 5 most expensive hosts in NYC. The combination of bar and line charts allows for a comprehensive analysis of these two different aspects of the data, enabling viewers to quickly grasp insights about host pricing and popularity.
#
# * **information gathered :**
# Price Comparison:
# The chart allows viewers to compare the prices of the top 5 most expensive hosts. The heights of the blue bars represent the prices of these hosts. This comparison provides a clear understanding of the price differences among these hosts.
#
#    Review Comparison:
# The orange line with markers shows the total number of reviews for each host. By having this information alongside the prices, viewers can assess how the number of reviews relates to the high prices. This is particularly useful to see if higher prices are correlated with a higher number of reviews.

# %% [markdown]
# # Conclusion -

# %% [markdown]
# **Conclusion: Enhancing Airbnb Insights for Optimal Experience**
#
# In the vast landscape of Airbnb data, our journey began with meticulous data exploration and cleansing. Armed with a refined dataset, our focus shifted to crafting illuminating visualizations. Let's distill the project's findings and insights into a cohesive conclusion:
#
# **Room Type Dynamics:**
# Insight: Entire homes are priced higher than private rooms and shared spaces, reflecting the demand for full accommodations. Hosts can strategize pricing based on room type preferences.
#
# **Geographical Insights:**
# Insight: Certain neighborhoods stand out in terms of listing density, making them prime areas for both hosts and guests. These insights guide tourists in choosing popular areas and assist hosts in market positioning.
#
# **Seasonal Pricing Patterns:**
# Insight: Pricing fluctuates with seasons; higher prices in peak months (January and December) indicate increased demand, potentially due to holidays or special events. Conversely, lower prices in August and March suggest off-peak periods.
#
# **Host Strategies:**
# Insight: Prolific hosts manage multiple properties, indicating successful Airbnb businesses. Luxury property hosts can leverage their premium offerings, while prolific hosts can optimize their portfolio.
#
# **Correlation and Customer Satisfaction:**
# Insight: Correlation analysis reveals factors influencing customer satisfaction. Higher prices do not necessarily correlate with more reviews, indicating guests prioritize value over cost.
#
# **Neighborhood Group Popularity:**
# Insight: Some neighborhood groups are exceptionally popular, providing a valuable starting point for tourists. Hosts can focus marketing efforts in these areas to attract more guests.
#
# **Availability and Booking Strategies:**
# Insight: Neighborhoods with higher availability can be targeted for strategic marketing, appealing to guests seeking last-minute bookings. Hosts can adjust availability to meet varying demands.
#
# **Continuous Monitoring:**
# Insight: The Airbnb market is dynamic. Continuous monitoring of seasonal trends, neighborhood popularity, and customer reviews is crucial for hosts to adapt their strategies and maximize revenue.
#
#
#
# > Recommendations:
# ---
#
#
# **Hosts:** Utilize seasonal trends to optimize pricing, enhance property listings, and focus on high-demand areas. Engage with customer reviews to improve service quality.
#
# **Guests:** Leverage insights on popular neighborhoods, seasonal pricing, and value-for-money options for a satisfying Airbnb experience.
#
# **Airbnb Platform:** Implement AI-driven tools for hosts, providing dynamic pricing suggestions based on seasonal demand and neighborhood popularity.
#
#
#
#
# In conclusion, this project offers a comprehensive view of the Airbnb landscape, equipping both hosts and guests with actionable insights. By embracing data-driven decisions, the Airbnb experience can be elevated, ensuring mutual satisfaction and fostering a thriving hospitality ecosystem.
